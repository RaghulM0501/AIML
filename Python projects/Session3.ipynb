# %%
var = 10

# %%
var
# Out:
# 10

# %%
type(var)
# Out:
# int

# %%
Str1 = :Raghul"
# Out:
#   Cell In[4], line 1
#     Str1 = :Raghul"
#                   ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
Str1 = "Raghul"

# %%
Str1
# Out:
# 'Raghul'

# %%
Str2 = '"Raghul"'

# %%
Str2
# Out:
# '"Raghul"'

# %%
STR1 = 'sdfsdf'

# %%
STR1
# Out:
# 'sdfsdf'

# %%
print(STR1)
# Out:
# sdfsdf
